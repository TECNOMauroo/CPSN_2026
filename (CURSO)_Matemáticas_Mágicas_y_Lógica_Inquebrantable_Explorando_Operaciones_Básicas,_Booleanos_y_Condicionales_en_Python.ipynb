# %% [markdown]
# <a href="https://colab.research.google.com/github/TECNOMauroo/CPSN_2026/blob/(CURSO)-Data-Science-Fundamentals-(certificaci%C3%B3n-docente-2026)/(CURSO)_Matem%C3%A1ticas_M%C3%A1gicas_y_L%C3%B3gica_Inquebrantable_Explorando_Operaciones_B%C3%A1sicas%2C_Booleanos_y_Condicionales_en_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. Operaciones Matemáticas Básicas en Python
# Las operaciones matemáticas son la base de muchos programas. Python proporciona una serie de operadores para realizar cálculos aritméticos de manera sencilla y directa.

# %%
# Suma (+): La suma se realiza utilizando el operador +.
# Este operador puede sumar tanto números enteros como números de punto flotante.

a = 10
b = 5
suma = a + b
print("La suma de a y b es:", suma)

# %%
# Resta (-): La resta se realiza utilizando el operador -

resta = a - b
print("La resta de a y b es:", resta)

# %%
# Multiplicación (*): La multiplicación se realiza utilizando el operador *.

multiplicacion = a * b
print("La multiplicación de a y b es:", multiplicacion)

# %%
# División (/): La división se realiza utilizando el operador /. La división siempre devuelve un número de punto flotante.

division = a / b
print("La división de a entre b es:", division)

# %%
# División Entera (//): La división entera devuelve el cociente sin el resto.

division_entera = a // b
print("La división entera de a entre b es:", division_entera)

# %%
# Módulo (%): El operador módulo devuelve el resto de la división.

modulo = a % b
print("El resto de la división de a entre b es:", modulo)

# %%
# Potencia (**):El operador de potencia eleva un número a la potencia de otro.

potencia = a ** b
print("a elevado a la potencia de b es:", potencia)

# %% [markdown]
# ### 2. Valores Booleanos
# Los valores booleanos son esenciales para la lógica en programación. En Python, los valores booleanos pueden ser True o False.

# %%
# Operadores de Comparación: Los operadores de comparación se utilizan
# para comparar dos valores y devuelven un valor booleano.

a = 10
b = 5

# ==: Igual a
print(a == b)  # False

# !=: Diferente de
print(a != b)  # True

# <: Menor que
print(a > b)   # True

# >: Mayor que
print(a < b)   # False

# <=: Menor o igual que
print(a >= b)  # True

# > =: Mayor o igual que
print(a <= b)  # False

# %%
# Operadores Lógicos: Los operadores lógicos se utilizan para combinar valores booleanos.

x = True
y = False

# and: Devuelve True si ambas expresiones son verdaderas
print(x and y)  # False

#or: Devuelve True si al menos una expresión es verdadera
print(x or y)   # True

#not: Invierte el valor booleano
print(not x)    # False

# %% [markdown]
# ### 3. Condicionales en Python
# Las estructuras condicionales permiten tomar decisiones en el código basadas en condiciones específicas. Las condicionales se construyen utilizando las palabras clave if, elif y else.

# %%
# Estructura Básica de if:  La estructura básica de un condicional if evalúa una expresión booleana
# y ejecuta el bloque de código correspondiente si la condición es verdadera.

a = 10
b = 5

if a > b:
    print("a es mayor que b")

# %%
# Uso de else: El bloque else se ejecuta si la condición if es falsa.

a = 10
b = 15

if a > b:
    print("a es mayor que b")
else:
    print("a no es mayor que b")

# %%
# Uso de elif: El bloque elif (abreviatura de «else if») permite comprobar múltiples condiciones.

a = 10
b = 10

if a > b:
    print("a es mayor que b")
elif a < b:
    print("a es menor que b")
else:
    print("a es igual a b")

# %%
# Condicionales Anidados: Puedes anidar condicionales dentro de otros condicionales
# para comprobar condiciones más complejas.

a = 10
b = 5
c = 15

if a > b:
    if a > c:
        print("a es el mayor")
    else:
        print("a es mayor que b pero menor o igual a c")
else:
    print("a no es mayor que b")
